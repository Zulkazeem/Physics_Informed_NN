# %% [markdown]
# # Importing Libraries

# %%
import torch
import pandas as pd
import numpy as np
from torch_geometric.data import Data
from matplotlib import cm
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import networkx as nx
import torch
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch_geometric.nn as pyg_nn
import torch.optim as optim
import torch.nn.functional as F
import random

# %%
torch.manual_seed(0)
random.seed(0)

# %% [markdown]
# # Loading the dataset

# %%
# 1. Load your CSV file into a pandas DataFrame
df = pd.read_csv(r"C:\Users\yomid\Downloads\Elasticity_Final_Report\Elasticity_Project_Pins\Data\new_merged_data.csv")

# %% [markdown]
# # Data Preprocessing

# %%
# 2. Extract Node Features (combine features for each node)
node_features = []
for index, row in df.iterrows():
    node_features.append([
        row['Soil Modulus (E_soil)'],     # E_soil
        row['Pressure at Node'],          # Pressure
        row['Spring Stiffness'],          # Spring Stiffness
        row['Pipe Burst Pressure'],       # Pipe Burst Pressure
        row['Temp'],                      # Temp
        row['Prev Temp'],                 # Prev Temp
        row['Displacement']               # Displacement
    ])

node_features = np.array(node_features)

# 3. Define Edges (Assume sequential connections for this example)
# Correct edge creation, ensuring last node (1055) is not out of bounds
edges = []
for i in range(len(df) - 1):  # len(df) - 1 prevents out-of-bounds errors
    edges.append([i, i + 1])

edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous()


# 4. Create Labels (1 for TRUE, 0 for FALSE)
labels = [1 if row['Burst Occurred'] else 0 for index, row in df.iterrows()]
labels = torch.tensor(labels, dtype=torch.float)

# 5. Convert Node Features to PyTorch tensor
x = torch.tensor(node_features, dtype=torch.float)

# 6. Create a PyTorch Geometric Data object
data = Data(x=x, edge_index=edge_index, y=labels)

# 7. Output the data object to verify
print(data)
# Out:
# Data(x=[1056, 7], edge_index=[2, 1055], y=[1056])

# %% [markdown]
# # Visualization

# %%
def visualize_graph(node_features, edge_index, temp_values, edge_attr=None):
    G = nx.Graph()
    for i, node_feature in enumerate(node_features):
        G.add_node(i, features=node_feature)
    
    num_edges = edge_index.size(1)
    for i in range(num_edges):
        source, target = edge_index[:, i].tolist()
        G.add_edge(source, target)

    fig, ax = plt.subplots(figsize=(10, 8))
    pos = nx.spring_layout(G, seed=42)
    node_labels = {i: f"{i}" for i in range(len(node_features))}
    
    # Use 'steelblue' for all nodes
    nx.draw(G, pos, ax=ax, with_labels=True, labels=node_labels, node_size=500, 
            node_color='steelblue', font_size=16, edge_color='lightsteelblue')

    plt.title("Pipe Graph Showing Current Temp")
    plt.savefig("Pipe_Graph_Temp.png", dpi=700)
    plt.tight_layout()
    plt.show()


# 9. Get the 'Temp' values for node coloring
temp_values = df['Temp'].tolist()

# 10. Ensure the same nodes are selected for edges
# For this pipe, select edges only involving the first 8 nodes
selected_edge_index = edge_index[:, :7]

# 11. Call the visualization function for the selected pipe
visualize_graph(node_features[:8], selected_edge_index, temp_values)

# %%
def visualize_graph(node_features, edge_index, temp_values, edge_attr=None):
    G = nx.Graph()
    for i, node_feature in enumerate(node_features):
        G.add_node(i, features=node_feature)
    
    num_edges = edge_index.size(1)
    for i in range(num_edges):
        source, target = edge_index[:, i].tolist()
        G.add_edge(source, target)

    fig, ax = plt.subplots(figsize=(10, 8))
    pos = nx.spring_layout(G, seed=42)
    node_labels = {i: f"{i}" for i in range(len(node_features))}
    
    # Use 'steelblue' for all nodes
    nx.draw(G, pos, ax=ax, with_labels=True, labels=node_labels, node_size=500, 
            node_color='maroon', font_size=16, font_color = "white",
            edge_color='lightsteelblue')

    plt.title("Pipe Graph Shwoing Previous Temp")
    plt.savefig("Pipe_Graph_Prev.png", dpi=700)
    plt.tight_layout()
    plt.show()


# 9. Get the 'Temp' values for node coloring
temp_values = df['Prev Temp'].tolist()

# 10. Ensure the same nodes are selected for edges
# For this pipe, select edges only involving the first 8 nodes
selected_edge_index = edge_index[:, :7]

# 11. Call the visualization function for the selected pipe
visualize_graph(node_features[:8], selected_edge_index, temp_values)

# %% [markdown]
# # Writng the torch Model

# %%
def burst_loss(out, data):
    """
    Burst loss function to enforce physical constraints on burst pressure.
    Args:
    - out: The predicted pressures (output of the model).
    - data: Data object containing node features (e.g., temperature, radius, thickness, etc.).
    Returns:
    - loss: The burst loss based on the predicted pressure and burst pressure criteria.
    """
    known_burst_pressure = 345e6  # Known burst pressure in Pascals (345 MPa)
    
    # Extract temperature change from dataset (e.g., Temp is in column 0 of data.x)
    temperature_change = data.x[:, 0] - 20  # Temperature change from base temperature (20°C)
    
    # Keep radius, thickness, and length constant (you can specify these values directly here)
    radius = 1.27  # Example: constant radius in meters
    thickness = 0.01  # Example: constant thickness in meters
    length = 1000  # Example: constant length in meters

    # Coefficient of thermal expansion for the material (example value for steel)
    alpha = 1.2e-5  # Coefficient of thermal expansion (1/°C)

    # Calculate change in radius and thickness due to temperature
    delta_radius = alpha * radius * temperature_change
    delta_thickness = alpha * thickness * temperature_change

    # Adjust radius and thickness due to thermal expansion
    adjusted_radius = radius + delta_radius
    adjusted_thickness = thickness + delta_thickness

    # Adjust yield strength due to temperature
    yield_strength_at_20C = 250e6  # Example yield strength at 20°C
    yield_strength_adjustment_factor = 1 - 0.005 * temperature_change  # Example adjustment
    adjusted_yield_strength = yield_strength_at_20C * yield_strength_adjustment_factor

    # Adjusted burst pressure due to temperature (using formula for burst pressure)
    adjusted_burst_pressure = adjusted_yield_strength * (adjusted_radius / adjusted_thickness)

    # Predicted pressure from the model
    predicted_pressure = out.squeeze()  # Predicted pressure (output)

    # Debugging: Check values of predicted and adjusted burst pressure
    print(f"Predicted pressure: {predicted_pressure}")
    print(f"Adjusted burst pressure: {adjusted_burst_pressure}")

    # Apply penalty if predicted pressure exceeds adjusted burst pressure
    penalty = torch.maximum(predicted_pressure - adjusted_burst_pressure, torch.zeros_like(predicted_pressure, device=out.device))

    # Debugging: Check penalty values
    print(f"Penalty: {penalty}")

    # Calculate burst difference between predicted and known burst pressure
    burst_difference = torch.abs(predicted_pressure - known_burst_pressure)

    # Normalize the burst difference
    normalized_burst_difference = burst_difference / known_burst_pressure

    # Total burst loss with a penalty term
    total_burst_loss = torch.mean(penalty + normalized_burst_difference) / 1e10  # Adjust scaling factor

    return total_burst_loss

# %%
# class GNNModel(torch.nn.Module):
#     def __init__(self, in_channels, out_channels):
#         super(GNNModel, self).__init__()
#         # First layer
#         self.conv1 = pyg_nn.GCNConv(in_channels, 64)  # Increase number of hidden units
#         self.conv2 = pyg_nn.GCNConv(64, 64)
#         self.conv3 = pyg_nn.GCNConv(64, 32)  # Smaller output layer
#         self.conv4 = pyg_nn.GCNConv(32, out_channels)
        
#         # Optional: Add Batch Normalization
#         self.batch_norm1 = torch.nn.BatchNorm1d(64)
#         self.batch_norm2 = torch.nn.BatchNorm1d(64)
#         self.batch_norm3 = torch.nn.BatchNorm1d(32)

#         # Dropout rate
#         self.dropout = 0.5

#     def forward(self, data):
#         x, edge_index = data.x, data.edge_index

#         # First convolution
#         x = self.conv1(x, edge_index)
#         x = F.relu(x)
#         x = self.batch_norm1(x)
#         x = F.dropout(x, p=self.dropout, training=self.training)
        
#         # Second convolution
#         x = self.conv2(x, edge_index)
#         x = F.relu(x)
#         x = self.batch_norm2(x)
#         x = F.dropout(x, p=self.dropout, training=self.training)
        
#         # Third convolution
#         x = self.conv3(x, edge_index)
#         x = F.relu(x)
#         x = self.batch_norm3(x)
#         x = F.dropout(x, p=self.dropout, training=self.training)

#         # Fourth convolution layer (final prediction)
#         x = self.conv4(x, edge_index)
        
#         return x

# %%
class GNNModel(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(GNNModel, self).__init__()
        self.conv1 = pyg_nn.GCNConv(in_channels, 128)  
        self.conv2 = pyg_nn.GCNConv(128, 128)
        self.conv3 = pyg_nn.GCNConv(128, 64)  # Output size is now 64
        self.conv4 = pyg_nn.GCNConv(64, out_channels)

        self.batch_norm1 = torch.nn.BatchNorm1d(128)
        self.batch_norm2 = torch.nn.BatchNorm1d(128)
        self.batch_norm3 = torch.nn.BatchNorm1d(64)

        self.dropout = 0.5
        
        # Linear transformation for adjusting dimensions
        self.linear_transform_1 = torch.nn.Linear(in_channels, 128)  # For conv1
        self.linear_transform_2 = torch.nn.Linear(128, 64)           # For conv3

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        
        # First convolution with residual connection
        x_res = self.linear_transform_1(x)  # Transforming x_res to match dimensions
        x = self.conv1(x, edge_index)
        x = F.relu(x + x_res)
        x = self.batch_norm1(x)
        x = F.dropout(x, p=self.dropout, training=self.training)

        # Second convolution
        x_res = x
        x = self.conv2(x, edge_index)
        x = F.relu(x + x_res)
        x = self.batch_norm2(x)
        x = F.dropout(x, p=self.dropout, training=self.training)

        # Third convolution with adjusted residual connection
        x_res = self.linear_transform_2(x_res)  # Transforming for matching dimensions
        x = self.conv3(x, edge_index)
        x = F.relu(x + x_res)
        x = self.batch_norm3(x)
        x = F.dropout(x, p=self.dropout, training=self.training)

        # Fourth convolution layer (final prediction)
        x = self.conv4(x, edge_index)

        return x

# %%
# Instantiate the model
model = GNNModel(in_channels=7, out_channels=1)  # 7 input features, 1 output (binary classification)
optimizer = optim.Adam(model.parameters(), lr=0.01)
loss_fn = torch.nn.BCEWithLogitsLoss()  # Binary Cross-Entropy loss for binary classification

# Training loop with Early Stopping and Learning Rate Scheduler
num_epochs = 500
best_loss = float('inf')
patience = 10  # Early stopping patience
counter = 0
alpha = 1e-6
# Learning rate scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

# %%
for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()
    
    # Forward pass
    out = model(data)
    
    # Compute the binary cross-entropy loss
    bce_loss = loss_fn(out.squeeze(), data.y)
    
    # Compute the burst loss
    physics_loss = burst_loss(out, data)
    
    # Combine the two losses (you can adjust the weight of each loss if necessary)
    total_loss = bce_loss + alpha * physics_loss
    
    # Backward pass
    total_loss.backward()
    optimizer.step()
    
    # Step the scheduler
    scheduler.step()

    # Print the loss every 10 epochs
    if epoch % 10 == 0:
        print(f'Epoch {epoch}, BCE Loss: {bce_loss.item()}, Physics Loss: {physics_loss.item()}, Total Loss: {total_loss.item()}')
    
    # Early stopping
    if total_loss.item() < best_loss:
        best_loss = total_loss.item()
        counter = 0
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping triggered!")
            break

# After training, evaluate the model
model.eval()
with torch.no_grad():
    out = model(data)
    predictions = torch.sigmoid(out).squeeze()
    predicted_labels = (predictions > 0.5).float()
    
    # You can now compute accuracy and confusion matrix
    accuracy = (predicted_labels == data.y).sum().item() / len(data.y)
    print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Predicted pressure: tensor([-0.6226, -2.4577, -1.9684,  ..., -0.3164, -0.5278, -0.0749],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Epoch 0, BCE Loss: 0.7840233445167542, Physics Loss: 4075782.75, Total Loss: 4.859806060791016
# Predicted pressure: tensor([-0.2908,  2.1723,  4.3804,  ..., -1.5064, -3.1697, -3.7057],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([ 1.3378,  2.4642,  3.4473,  ..., -0.2461, -0.1788,  0.1476],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([-0.2071, -0.8368,  0.0522,  ...,  1.3035,  2.5839,  3.2481],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([-1.7971, -0.2612,  1.6684,  ...,  1.0779,  1.7893,  1.9972],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([3.6330, 4.3446, 4.6761,  ..., 1.8430, 2.5895, 1.6896],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([ 5.0912,  5.3691,  3.8074,  ...,  0.9357,  1.0247, -0.1438],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([ 7.3084, 11.0589,  8.1610,  ...,  1.0723,  0.9309,  1.3979],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([ 3.5952,  4.3686,  4.4517,  ..., -0.3648,  0.2127,  0.9279],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([3.9093, 4.6526, 5.1010,  ..., 2.0330, 2.0639, 2.9434],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.6890, 5.2747, 4.1160,  ..., 2.4035, 2.1661, 2.0640],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Epoch 10, BCE Loss: 0.2831183075904846, Physics Loss: 4075782.75, Total Loss: 4.358901023864746
# Predicted pressure: tensor([1.0978, 0.5704, 0.9180,  ..., 1.8756, 3.3092, 2.7519],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([3.8565, 4.4097, 4.4382,  ..., 2.7302, 1.7279, 1.4866],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([2.7177, 2.7366, 2.5075,  ..., 3.4500, 2.1014, 2.4889],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([5.3405, 5.2789, 4.8178,  ..., 1.8681, 2.5058, 2.4483],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([2.8575, 4.1701, 3.5466,  ..., 1.7584, 1.7829, 1.7845],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.4935, 4.9331, 4.2117,  ..., 2.2295, 1.6673, 1.2533],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.9763, 5.6197, 4.5348,  ..., 2.9901, 2.9104, 2.3943],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([3.6592, 3.5369, 2.8605,  ..., 1.6297, 2.1326, 3.1627],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.2724, 3.5983, 2.6604,  ..., 3.7952, 4.4663, 3.4729],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.6460, 4.0521, 2.8871,  ..., 3.8186, 3.1174, 2.3091],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Epoch 20, BCE Loss: 0.20304416120052338, Physics Loss: 4075782.75, Total Loss: 4.278826713562012
# Predicted pressure: tensor([4.9629, 5.7330, 4.8220,  ..., 3.2307, 2.9185, 3.8439],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.0594, 4.3035, 3.2723,  ..., 3.8714, 3.1645, 4.2707],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([2.5528, 3.3191, 3.9912,  ..., 4.1347, 3.1101, 2.6703],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([3.0855, 4.0091, 2.5488,  ..., 5.9107, 4.8945, 4.2913],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([2.7015, 2.5025, 3.0520,  ..., 3.9324, 3.8784, 4.6981],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([5.5733, 5.8421, 5.4565,  ..., 2.8381, 2.8397, 3.2380],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([3.7925, 3.2299, 3.3043,  ..., 3.7331, 3.4572, 4.7147],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([2.0299, 2.5933, 2.9294,  ..., 4.7520, 4.5841, 4.1221],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([6.0815, 6.0272, 2.8147,  ..., 3.9371, 3.9282, 3.3584],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.4236, 5.5168, 3.8720,  ..., 4.9895, 4.8497, 4.0345],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Epoch 30, BCE Loss: 0.1464870125055313, Physics Loss: 4075782.75, Total Loss: 4.2222700119018555
# Predicted pressure: tensor([4.2297, 4.6695, 4.1613,  ..., 3.5754, 2.9669, 3.3207],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.2176, 3.5632, 3.0053,  ..., 3.4952, 5.2002, 6.0041],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([3.3155, 2.8423, 1.9439,  ..., 4.8288, 2.9217, 2.9721],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([2.2052, 2.9812, 3.7346,  ..., 4.8430, 6.8160, 5.4937],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([5.4764, 5.9101, 2.9313,  ..., 3.4069, 3.7151, 4.5154],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.6414, 5.3318, 4.6951,  ..., 4.5781, 3.8479, 3.0223],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.2728, 4.7746, 3.2974,  ..., 1.6196, 3.5031, 5.3506],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.8457, 5.3919, 4.7696,  ..., 3.3934, 3.5997, 5.7529],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([5.2302, 5.0649, 4.0072,  ..., 4.3765, 4.2227, 5.7618],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.5376, 2.6669, 1.9498,  ..., 3.8738, 4.9996, 5.5722],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Epoch 40, BCE Loss: 0.11834199726581573, Physics Loss: 4075782.75, Total Loss: 4.194124698638916
# Predicted pressure: tensor([3.9750, 4.0225, 4.1671,  ..., 4.2924, 4.4062, 3.9415],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([6.2927, 3.4113, 0.4071,  ..., 4.3321, 5.0571, 3.5733],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([3.0925, 3.7305, 3.2189,  ..., 3.5513, 4.8294, 5.7958],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([6.4564, 5.2673, 2.5871,  ..., 4.5433, 4.2512, 4.2232],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([6.8440, 5.5878, 2.7290,  ..., 5.2368, 5.8194, 5.0748],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([2.6197, 3.3430, 3.9002,  ..., 4.9715, 5.4394, 4.0404],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.2972, 5.3645, 5.4852,  ..., 5.8732, 5.8995, 5.1132],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.7752, 4.1398, 3.3468,  ..., 5.9234, 6.2758, 5.2465],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([5.7466, 4.8111, 3.6543,  ..., 3.7858, 4.1551, 4.6067],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([6.1749, 5.4650, 3.3403,  ..., 5.2912, 5.4301, 4.7335],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Epoch 50, BCE Loss: 0.1169213056564331, Physics Loss: 4075782.75, Total Loss: 4.192704200744629
# Predicted pressure: tensor([3.6857, 1.9883, 2.6828,  ..., 5.4130, 4.8340, 3.8405],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([6.9697, 7.2935, 4.7163,  ..., 3.7382, 3.5302, 3.7256],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([9.6732, 7.9931, 4.0287,  ..., 4.8235, 4.1634, 3.6647],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([2.5802, 2.8800, 2.7539,  ..., 4.0155, 4.3908, 4.7276],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.9255, 4.5253, 2.8528,  ..., 4.6848, 3.8247, 4.7504],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([2.0752, 2.6847, 4.5128,  ..., 5.2534, 4.2496, 4.5637],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([5.2943, 5.3891, 4.7334,  ..., 5.0282, 4.2838, 4.7685],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.4256, 4.6770, 3.6803,  ..., 4.5667, 4.2418, 4.1205],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.1780, 4.4003, 5.2551,  ..., 5.6984, 4.4495, 2.9242],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([5.7628, 4.5210, 2.9978,  ..., 7.4984, 6.7417, 5.4221],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Epoch 60, BCE Loss: 0.11174563318490982, Physics Loss: 4075782.75, Total Loss: 4.187528610229492
# Predicted pressure: tensor([5.3764, 6.8859, 7.4921,  ..., 3.7165, 5.6318, 7.1395],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.9522, 5.6562, 5.1648,  ..., 5.9948, 5.5426, 4.5640],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([3.7654, 4.0250, 3.9351,  ..., 5.6295, 4.1508, 3.3387],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([5.8129, 5.5066, 3.3605,  ..., 4.3806, 4.5354, 4.7653],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([6.9613, 5.5863, 2.9175,  ..., 5.2292, 6.4884, 6.0917],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([2.1594, 3.0039, 2.9191,  ..., 3.9920, 4.6593, 4.5304],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.3120, 3.5904, 2.9901,  ..., 5.0202, 4.1197, 4.7854],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([3.1053, 2.8938, 2.7253,  ..., 5.5392, 4.7063, 4.8955],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([5.3022, 3.8799, 1.7894,  ..., 4.2542, 4.0224, 3.0485],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.2064, 4.8319, 4.5019,  ..., 4.7130, 4.8983, 6.0186],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Epoch 70, BCE Loss: 0.10401180386543274, Physics Loss: 4075782.75, Total Loss: 4.179794788360596
# Predicted pressure: tensor([4.1726, 4.0231, 4.6334,  ..., 9.0589, 6.8873, 4.0782],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([4.7406, 3.1976, 2.4446,  ..., 5.0792, 4.6051, 5.2311],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Predicted pressure: tensor([6.5175, 5.9084, 3.2419,  ..., 5.4622, 5.1900, 5.5987],
#        grad_fn=<SqueezeBackward0>)
# Adjusted burst pressure: tensor([-1.0795e+17, -1.0795e+17, -1.0795e+17,  ..., -7.9375e+15,
#         -7.9375e+15, -7.9375e+15])
# Penalty: tensor([1.0795e+17, 1.0795e+17, 1.0795e+17,  ..., 7.9375e+15, 7.9375e+15,
#         7.9375e+15], grad_fn=<MaximumBackward0>)
# Early stopping triggered!
# Accuracy: 98.01%

# %%
# Evaluate model (assumes data is in the same format as training data)
def evaluate_model(model, data):
    model.eval()  # Set model to evaluation mode

    # Forward pass (get predictions)
    with torch.no_grad():
        out = model(data)  # Logits from the model
        predictions = torch.sigmoid(out).squeeze()  # Apply sigmoid to get probabilities
        predicted_labels = (predictions > 0.5).float()  # Convert probabilities to binary predictions

    # Calculate accuracy
    accuracy = (predicted_labels == data.y).sum().item() / len(data.y)
    
    # Confusion Matrix
    cm = metrics.confusion_matrix(data.y.cpu(), predicted_labels.cpu())
    
    return accuracy, cm

# Example usage
accuracy, cm = evaluate_model(model, data)

# Print accuracy
print(f"Accuracy: {accuracy * 100:.2f}%")

# Plot confusion matrix
def plot_confusion_matrix(cm, labels=["Class 0", "Class 1"]):
    # Plot confusion matrix as a heatmap
    fig, ax = plt.subplots(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels, cbar=False)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')
    ax.set_title('Confusion Matrix')
    plt.savefig("GNN_with_PL.png", dpi = 700)
    plt.show()

# Call function to plot the confusion matrix
plot_confusion_matrix(cm)
# Out:
# Accuracy: 98.01%

# %%
from sklearn import metrics

def evaluate_model(model, data):
    model.eval()  # Set model to evaluation mode

    # Forward pass (get predictions)
    with torch.no_grad():
        out = model(data)  # Logits from the model
        predictions = torch.sigmoid(out).squeeze()  # Apply sigmoid to get probabilities
        predicted_labels = (predictions > 0.5).float()  # Convert probabilities to binary predictions

    # Calculate accuracy
    accuracy = (predicted_labels == data.y).sum().item() / len(data.y)
    
    # Confusion Matrix
    cm = metrics.confusion_matrix(data.y.cpu(), predicted_labels.cpu())
    tn, fp, fn, tp = cm.ravel()  # Extract values from the confusion matrix

    # Calculate Precision, Recall, Specificity, and F1-Score
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    return accuracy, cm, precision, recall, specificity, f1_score

# Example usage
accuracy, cm, precision, recall, specificity, f1_score = evaluate_model(model, data)

# Print metrics
print(f"Accuracy: {accuracy * 100:.2f}%")
print(f"Precision: {precision * 100:.2f}%")
print(f"Recall: {recall * 100:.2f}%")
print(f"Specificity: {specificity * 100:.2f}%")
print(f"F1-Score: {f1_score * 100:.2f}%")

# Plot confusion matrix
def plot_confusion_matrix(cm, labels=["Class 0", "Class 1"]):
    # Plot confusion matrix as a heatmap
    fig, ax = plt.subplots(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels, cbar=False)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')
    ax.set_title('Confusion Matrix')
    plt.savefig("GNN_with_PL.png", dpi=700)
    plt.show()

# Call function to plot the confusion matrix
plot_confusion_matrix(cm)
# Out:
# Accuracy: 98.01%
# Precision: 98.73%
# Recall: 98.31%
# Specificity: 97.38%
# F1-Score: 98.52%

# %% [markdown]
# # Single Prediction

# %%
import torch
import numpy as np
import pandas as pd
from torch_geometric.data import Data

# Load your trained model
model.eval()  # Set the model to evaluation mode

# Load the CSV file
df = pd.read_csv(r"C:\Users\yomid\Downloads\Elasticity_Final_Report\Elasticity_Project_Pins\Data\new_merged_data.csv")

# %%
# Select the row (e.g., first row)
row = df.iloc[181]

# Prepare node features
node_features = np.array([
    row['Soil Modulus (E_soil)'],  # E_soil
    row['Pressure at Node'],       # Pressure
    row['Spring Stiffness'],       # Spring Stiffness
    row['Pipe Burst Pressure'],    # Pipe Burst Pressure
    row['Temp'],                   # Temp
    row['Prev Temp'],              # Prev Temp
    row['Displacement']            # Displacement
])

# Convert to tensor and add batch dimension (unsqueeze)
x = torch.tensor(node_features, dtype=torch.float).unsqueeze(0)

# Add self-loop to edge_index for a single node
edge_index = torch.tensor([[0, 0]], dtype=torch.long).t().contiguous()  # A self-loop for a single node

# Create a dummy label for the Data object (can be any value as we only need x and edge_index)
y = torch.tensor([0], dtype=torch.float)

# Create the Data object for PyTorch Geometric
data = Data(x=x, edge_index=edge_index, y=y)

# Make prediction
with torch.no_grad():
    out = model(data)

# Apply sigmoid for probability
predictions = torch.sigmoid(out).squeeze()  # Remove batch dimension

# Convert to binary classification
predicted_label = (predictions > 0.5).float()  # 0 or 1

# Print result
print(f"Predicted Burst (0=No, 1=Yes): {predicted_label.item()}")
# Out:
# Predicted Burst (0=No, 1=Yes): 1.0
